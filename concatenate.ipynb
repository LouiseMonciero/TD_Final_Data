# %%
import pandas as pd
# Données qu'on a extrait
df1 = pd.read_csv('./data/data.zip')
df1
# Out:
# C:\Users\eva2p\AppData\Local\Temp\ipykernel_22276\2602116425.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('./data/data.zip')
#                     ID_ANSSI  \
# 0       CERTFR-2024-AVI-0465
# 1       CERTFR-2024-AVI-0936
# 2       CERTFR-2024-AVI-0936
# 3       CERTFR-2024-AVI-0936
# 4       CERTFR-2024-AVI-0936
# ...                      ...
# 102181   CERTFR-2025-ALE-006
# 102182   CERTFR-2025-ALE-006
# 102183   CERTFR-2025-ALE-006
# 102184   CERTFR-2025-ALE-006
# 102185   CERTFR-2025-ALE-006
#
#                                                     Titre    Type  \
# 0                      Vulnérabilité dans MongoDB PyMongo    Avis
# 1       Multiples vulnérabilités dans les produits Splunk    Avis
# 2       Multiples vulnérabilités dans les produits Splunk    Avis
# 3       Multiples vulnérabilités dans les produits Splunk    Avis
# 4       Multiples vulnérabilités dans les produits Splunk    Avis
# ...

# %%
# Données fournies par le coordinateur
df2 = pd.read_csv('./data_pour_TD_final/data.csv.zip')
df2.head()
# Out:
# C:\Users\eva2p\AppData\Local\Temp\ipykernel_22276\534783491.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('./data_pour_TD_final/data.csv.zip')
#                ID_ANSSI                                              Titre  \
# 0  CERTFR-2024-AVI-0465                 Vulnérabilité dans MongoDB PyMongo
# 1  CERTFR-2025-AVI-0368  Multiples vulnérabilités dans le noyau Linux d...
# 2  CERTFR-2025-AVI-0368  Multiples vulnérabilités dans le noyau Linux d...
# 3  CERTFR-2025-AVI-0368  Multiples vulnérabilités dans le noyau Linux d...
# 4  CERTFR-2025-AVI-0368  Multiples vulnérabilités dans le noyau Linux d...
#
#    Type                        Date             CVE  CVSS Base Severity  \
# 0  Avis  2024-06-06T07:11:10.939677   CVE-2024-5629   4.7       Moyenne
# 1  Avis  2025-05-02T00:00:00.000000  CVE-2024-50063   NaN           NaN
# 2  Avis  2025-05-02T00:00:00.000000  CVE-2024-50063   NaN           NaN
# ...

# %% [markdown]
# Concaténation des deux DataFrame pour obtnenir notre donnée finale

# %%
df_final = pd.concat([df1, df2])
df_final = df_final.drop_duplicates()

# %%
df_final.shape
# Out:
# (225314, 16)

# %%
df_final
# Out:
#                     ID_ANSSI  \
# 0       CERTFR-2024-AVI-0465
# 1       CERTFR-2024-AVI-0936
# 2       CERTFR-2024-AVI-0936
# 3       CERTFR-2024-AVI-0936
# 4       CERTFR-2024-AVI-0936
# ...                      ...
# 134241   CERTFR-2021-ALE-012
# 134242   CERTFR-2021-ALE-012
# 134243   CERTFR-2021-ALE-012
# 134244   CERTFR-2022-ALE-010
# 134245   CERTFR-2022-ALE-010
#
#                                                     Titre    Type  \
# 0                      Vulnérabilité dans MongoDB PyMongo    Avis
# 1       Multiples vulnérabilités dans les produits Splunk    Avis
# 2       Multiples vulnérabilités dans les produits Splunk    Avis
# 3       Multiples vulnérabilités dans les produits Splunk    Avis
# 4       Multiples vulnérabilités dans les produits Splunk    Avis
# ...                                                   ...     ...
# 134241    Multiples vulnérabilités dans Microsoft Windows  Alerte
# 134242    Multiples vulnérabilités dans Microsoft Windows  Alerte
# ...

# %%
df_final.to_csv('./data/final_data.csv', index=False)

# %%
"""
df_final.dropna(inplace = True)
df_final.shape
"""
# Out:
# (109369, 16)
